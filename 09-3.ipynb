# %% [markdown]
# <a href="https://colab.research.google.com/github/kshelp/hg-mldl2/blob/main/09-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LSTM과 GRU 셀

# %%
# 실행마다 동일한 결과를 얻기 위해 케라스에 랜덤 시드를 사용하고 텐서플로 연산을 결정적으로 만듭니다.
import keras
import tensorflow as tf

keras.utils.set_random_seed(42)
tf.random.set_seed(42)
tf.config.experimental.enable_op_determinism()

# %% [markdown]
# ## LSTM 신경망 훈련하기

# %%
from keras.datasets import imdb
from sklearn.model_selection import train_test_split

(train_input, train_target), (test_input, test_target) = imdb.load_data(
    num_words=500)
train_input, val_input, train_target, val_target = train_test_split(
    train_input, train_target, test_size=0.2, random_state=42)

from keras.preprocessing.sequence import pad_sequences

train_seq = pad_sequences(train_input, maxlen=100)
val_seq = pad_sequences(val_input, maxlen=100)

import keras

model_lstm = keras.Sequential()
model_lstm.add(keras.layers.Input(shape=(100,)))
model_lstm.add(keras.layers.Embedding(500, 16))
model_lstm.add(keras.layers.LSTM(8))
model_lstm.add(keras.layers.Dense(1, activation='sigmoid'))
model_lstm.summary()

model_lstm.compile(optimizer='adam', loss='binary_crossentropy',
                   metrics=['accuracy'])
checkpoint_cb = keras.callbacks.ModelCheckpoint('best-lstm-model.keras',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)
history = model_lstm.fit(train_seq, train_target, epochs=100, batch_size=64,
                         validation_data=(val_seq, val_target),
                         callbacks=[checkpoint_cb, early_stopping_cb])

import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 8)              │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,809 (34.41 KB)
#  Trainable params: 8,809 (34.41 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.6872 - loss: 0.5841 - val_accuracy: 0.7632 - val_loss: 0.4902
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7858 - loss: 0.4692 - val_accuracy: 0.7874 - val_loss: 0.4556
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7980 - loss: 0.4445 - val_accuracy: 0.7922 - val_loss: 0.4437
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8033 - loss: 0.4307 - val_accuracy: 0.7940 - val_loss: 0.4417
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8053 - loss: 0.4216 - val_accuracy: 0.7964 - val_loss: 0.4382
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8099 - loss: 0.4140 - val_accuracy: 0.7986 - val_loss: 0.4358
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8123 - loss: 0.4077 - val_accuracy: 0.7998 - val_loss: 0.4331
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8136 - loss: 0.4026 - val_accuracy: 0.7992 - val_loss: 0.4304
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8148 - loss: 0.3982 - val_accuracy: 0.8024 - val_loss: 0.4277
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8167 - loss: 0.3941 - val_accuracy: 0.8020 - val_loss: 0.4251
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8193 - loss: 0.3906 - val_accuracy: 0.8056 - val_loss: 0.4229
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8219 - loss: 0.3875 - val_accuracy: 0.8070 - val_loss: 0.4218
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8199 - loss: 0.3844 - val_accuracy: 0.8058 - val_loss: 0.4218
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8218 - loss: 0.3804 - val_accuracy: 0.8062 - val_loss: 0.4217
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8247 - loss: 0.3743 - val_accuracy: 0.8092 - val_loss: 0.4234
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8278 - loss: 0.3700 - val_accuracy: 0.8086 - val_loss: 0.4240
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8286 - loss: 0.3669 - val_accuracy: 0.8088 - val_loss: 0.4233

# %% [markdown]
# ## 순환 층에 드롭아웃 적용하기

# %%
model_dropout = keras.Sequential()
model_dropout.add(keras.layers.Input(shape=(100,)))
model_dropout.add(keras.layers.Embedding(500, 16))
model_dropout.add(keras.layers.LSTM(8, dropout=0.3))
model_dropout.add(keras.layers.Dense(1, activation='sigmoid'))

model_dropout.compile(optimizer='adam', loss='binary_crossentropy',
                      metrics=['accuracy'])
checkpoint_cb = keras.callbacks.ModelCheckpoint('best-dropout-model.keras',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)
history = model_dropout.fit(train_seq, train_target, epochs=100, batch_size=64,
                            validation_data=(val_seq, val_target),
                            callbacks=[checkpoint_cb, early_stopping_cb])

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6787 - loss: 0.5931 - val_accuracy: 0.7732 - val_loss: 0.4870
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7770 - loss: 0.4765 - val_accuracy: 0.7894 - val_loss: 0.4484
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7928 - loss: 0.4490 - val_accuracy: 0.7910 - val_loss: 0.4437
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7955 - loss: 0.4382 - val_accuracy: 0.7916 - val_loss: 0.4477
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8015 - loss: 0.4294 - val_accuracy: 0.8002 - val_loss: 0.4318
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8052 - loss: 0.4215 - val_accuracy: 0.7980 - val_loss: 0.4336
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8084 - loss: 0.4170 - val_accuracy: 0.8036 - val_loss: 0.4239
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8084 - loss: 0.4122 - val_accuracy: 0.8026 - val_loss: 0.4266
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8104 - loss: 0.4084 - val_accuracy: 0.8034 - val_loss: 0.4261
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8133 - loss: 0.4051 - val_accuracy: 0.8062 - val_loss: 0.4242

# %% [markdown]
# ## 2개의 층을 연결하기

# %%
model_2lstm = keras.Sequential()
model_2lstm.add(keras.layers.Input(shape=(100,)))
model_2lstm.add(keras.layers.Embedding(500, 16))
model_2lstm.add(keras.layers.LSTM(8, dropout=0.2, return_sequences=True))
model_2lstm.add(keras.layers.LSTM(8, dropout=0.2))
model_2lstm.add(keras.layers.Dense(1, activation='sigmoid'))
model_2lstm.summary()

model_2lstm.compile(optimizer='adam', loss='binary_crossentropy',
                     metrics=['accuracy'])
checkpoint_cb = keras.callbacks.ModelCheckpoint('best-2lstm-model.keras',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)
history = model_2lstm.fit(train_seq, train_target, epochs=100, batch_size=64,
                          validation_data=(val_seq, val_target),
                          callbacks=[checkpoint_cb, early_stopping_cb])

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 100, 8)         │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_10 (LSTM)                  │ (None, 8)              │           544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9,353 (36.54 KB)
#  Trainable params: 9,353 (36.54 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.6574 - loss: 0.6126 - val_accuracy: 0.7472 - val_loss: 0.5247
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7728 - loss: 0.4935 - val_accuracy: 0.7686 - val_loss: 0.4866
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7891 - loss: 0.4609 - val_accuracy: 0.7926 - val_loss: 0.4450
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7988 - loss: 0.4423 - val_accuracy: 0.7922 - val_loss: 0.4468
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8033 - loss: 0.4301 - val_accuracy: 0.7960 - val_loss: 0.4373
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8069 - loss: 0.4221 - val_accuracy: 0.7960 - val_loss: 0.4353
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8109 - loss: 0.4125 - val_accuracy: 0.8082 - val_loss: 0.4229
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8181 - loss: 0.4034 - val_accuracy: 0.7960 - val_loss: 0.4331
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8198 - loss: 0.3984 - val_accuracy: 0.8080 - val_loss: 0.4191
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8235 - loss: 0.3921 - val_accuracy: 0.8106 - val_loss: 0.4121
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8258 - loss: 0.3858 - val_accuracy: 0.8158 - val_loss: 0.4075
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8243 - loss: 0.3822 - val_accuracy: 0.8144 - val_loss: 0.4075
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8338 - loss: 0.3733 - val_accuracy: 0.8156 - val_loss: 0.4121
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8338 - loss: 0.3741 - val_accuracy: 0.8140 - val_loss: 0.4048
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8342 - loss: 0.3679 - val_accuracy: 0.8146 - val_loss: 0.4043
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8342 - loss: 0.3677 - val_accuracy: 0.8124 - val_loss: 0.4109
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8346 - loss: 0.3638 - val_accuracy: 0.8178 - val_loss: 0.4039
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8393 - loss: 0.3614 - val_accuracy: 0.8158 - val_loss: 0.4007
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8378 - loss: 0.3628 - val_accuracy: 0.8132 - val_loss: 0.4027
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8397 - loss: 0.3604 - val_accuracy: 0.8178 - val_loss: 0.4012
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8421 - loss: 0.3541 - val_accuracy: 0.8088 - val_loss: 0.4110

# %% [markdown]
# ## GRU 신경망 훈련하기

# %%
model_gru = keras.Sequential()
model_gru.add(keras.layers.Input(shape=(100,)))
model_gru.add(keras.layers.Embedding(500, 16))
model_gru.add(keras.layers.GRU(8, dropout=0.2))
model_gru.add(keras.layers.Dense(1, activation='sigmoid'))
model_gru.summary()

model_gru.compile(optimizer='adam', loss='binary_crossentropy',
                  metrics=['accuracy'])
checkpoint_cb = keras.callbacks.ModelCheckpoint('best-gru-model.keras',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                  restore_best_weights=True)
history = model_gru.fit(train_seq, train_target, epochs=100, batch_size=64,
                        validation_data=(val_seq, val_target),
                        callbacks=[checkpoint_cb, early_stopping_cb])

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

test_seq = pad_sequences(test_input, maxlen=100)
best_model = keras.models.load_model('best-gru-model.keras')
best_model.evaluate(test_seq, test_target)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 100, 16)        │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 8)              │           624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,633 (33.72 KB)
#  Trainable params: 8,633 (33.72 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6409 - loss: 0.6187 - val_accuracy: 0.7658 - val_loss: 0.4944
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7683 - loss: 0.4890 - val_accuracy: 0.7718 - val_loss: 0.4801
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7876 - loss: 0.4615 - val_accuracy: 0.7810 - val_loss: 0.4668
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.7987 - loss: 0.4427 - val_accuracy: 0.7896 - val_loss: 0.4508
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7999 - loss: 0.4323 - val_accuracy: 0.7920 - val_loss: 0.4428
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8048 - loss: 0.4273 - val_accuracy: 0.7980 - val_loss: 0.4333
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8081 - loss: 0.4193 - val_accuracy: 0.8008 - val_loss: 0.4309
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8102 - loss: 0.4167 - val_accuracy: 0.8056 - val_loss: 0.4269
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8119 - loss: 0.4128 - val_accuracy: 0.8038 - val_loss: 0.4254
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8151 - loss: 0.4073 - val_accuracy: 0.8074 - val_loss: 0.4228
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8162 - loss: 0.4042 - val_accuracy: 0.8110 - val_loss: 0.4195
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8208 - loss: 0.3993 - val_accuracy: 0.8108 - val_loss: 0.4182
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8220 - loss: 0.3943 - val_accuracy: 0.8076 - val_loss: 0.4187
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8248 - loss: 0.3905 - val_accuracy: 0.8096 - val_loss: 0.4178
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8260 - loss: 0.3874 - val_accuracy: 0.8128 - val_loss: 0.4129
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8250 - loss: 0.3838 - val_accuracy: 0.8140 - val_loss: 0.4150
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8291 - loss: 0.3807 - val_accuracy: 0.8128 - val_loss: 0.4165
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8315 - loss: 0.3769 - val_accuracy: 0.8148 - val_loss: 0.4176
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8151 - loss: 0.4070
# [0.40704062581062317, 0.8150799870491028]
